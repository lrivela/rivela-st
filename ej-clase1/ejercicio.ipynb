# %% [markdown]
# ## Ejercicio 1
#
# #### Alumno: Lucas Rivela
# #### Cohorte: 5
# #### Profesores: Magdalena Bouza y Carlos Romano

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# Punto 1

# %%
x = np.linspace(0, 10, 100)
noise = np.random.normal(0, 5, 100)

y = x**2
y = y + noise

# %%
plt.figure(figsize=(10,7))
plt.plot(x, y)
plt.xlabel('Tiempo')
plt.ylabel('Valores')
plt.title('Funcion cuadratica con ruido gaussiano media nula y varianza 5')
# Out:
# Text(0.5, 1.0, 'Funcion cuadratica con ruido gaussiano media nula y varianza 5')

# %% [markdown]
# Punto 2

# %%
df = pd.read_csv('./YPFD.2000.2021.csv')
df.drop(columns=['Unnamed: 0'], inplace=True)
df.head()
# Out:
#                  fechaHora  ultimoPrecio
# 0  2021-06-29 17:00:01.710        783.15
# 1  2021-06-28 17:00:03.613        807.00
# 2  2021-06-25 17:00:02.397        831.65
# 3  2021-06-24 17:00:03.497        871.40
# 4  2021-06-23 17:00:03.290        857.65

# %%
df.isna().sum()
# Out:
# fechaHora       0
# ultimoPrecio    0
# dtype: int64

# %%
df.describe()
# Out:
#        ultimoPrecio
# count   4840.000000
# mean     115.680014
# std      239.699517
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max      950.050000

# %%
df['ultimoPrecio'].to_numpy().ravel().shape
# Out:
# (4840,)

# %%
plt.figure(figsize=(10,7))
plt.plot(range(len(df['ultimoPrecio'])), df['ultimoPrecio'].to_numpy())
plt.xlabel('Tiempo')
plt.ylabel('Valores')
plt.title('YPFD.2000.2021')
# Out:
# Text(0.5, 1.0, 'YPFD.2000.2021')

# %% [markdown]
# Punto 3

# %%
bitcoin = pd.read_csv('./coin_Bitcoin.csv')
bitcoin.head()
# Out:
#    SNo     Name Symbol                 Date        High         Low  \
# 0    1  Bitcoin    BTC  2013-04-29 23:59:59  147.488007  134.000000
# 1    2  Bitcoin    BTC  2013-04-30 23:59:59  146.929993  134.050003
# 2    3  Bitcoin    BTC  2013-05-01 23:59:59  139.889999  107.720001
# 3    4  Bitcoin    BTC  2013-05-02 23:59:59  125.599998   92.281898
# 4    5  Bitcoin    BTC  2013-05-03 23:59:59  108.127998   79.099998
#
#          Open       Close  Volume     Marketcap
# 0  134.444000  144.539993     0.0  1.603769e+09
# 1  144.000000  139.000000     0.0  1.542813e+09
# 2  139.000000  116.989998     0.0  1.298955e+09
# 3  116.379997  105.209999     0.0  1.168517e+09
# 4  106.250000   97.750000     0.0  1.085995e+09

# %%
bitcoin.isna().sum().sum()
# Out:
# 0

# %%
strformat = pd.to_datetime(bitcoin["Date"])
#strformat = bitcoin["Date"].apply(lambda row: row.format("%m/%d/%Y"))

plt.figure(figsize=(10,7))
#plt.plot(range(len(strformat.to_numpy())), bitcoin['Close'].to_numpy())
sns.lineplot(strformat, bitcoin['Close'], x='Tiempo', y='Valor')
plt.xlabel('Tiempo')
plt.ylabel('Valores')
plt.title('Bitcoin-USD')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Bitcoin-USD')

# %% [markdown]
# En este gráfico se muestra el precio del Bitcoin por día desde 2013 hasta 2021.

# %%
oil = pd.read_csv('./BrentOilPrices.csv')
oil.head()
# Out:
#         Date  Price
# 0  20-May-87  18.63
# 1  21-May-87  18.45
# 2  22-May-87  18.55
# 3  25-May-87  18.60
# 4  26-May-87  18.63

# %%
oil.isna().sum()
# Out:
# Date     0
# Price    0
# dtype: int64

# %%
dat = pd.to_datetime(oil["Date"])

plt.figure(figsize=(10,7))
sns.lineplot(dat, oil['Price'])
plt.xlabel('Tiempo')
plt.ylabel('Valores')
plt.title('Petroleo-USD')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Petroleo-USD')

# %%
df1 = pd.read_csv('./1979-2021.csv')[["Date", "United States(USD)"]]

# %%
df1.isna().sum()
# Out:
# Date                  0
# United States(USD)    0
# dtype: int64

# %%
serie = pd.to_datetime(df1["Date"], infer_datetime_format=True)

plt.figure(figsize=(10,7))
sns.lineplot(serie, df1['United States(USD)'])
plt.xlabel('Tiempo')
plt.ylabel('Valores')
plt.title('Oro-USD')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Oro-USD')
